# %% [markdown]
# # Flood-It Environment Explorer
#
# Simple interactive notebook to explore the Flood-It Gymnasium environment.
#
# ## Usage:
# - Call `reset()` to start a new game
# - Call `step(color)` to flood with a color (0-5)
# - Check `env.board`, `env.moves_used`, `env.solved` for current state

# %%
from floodit_env import FloodItEnv

# Create environment (no rendering)
env = FloodItEnv()

print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}")
print(f"Board size: {env.observation_space.shape}")
# Out:
# Observation space: Box(0, 5, (14, 14), int64)
# Action space: Discrete(6)
# Board size: (14, 14)

# %%
# Reset the environment to get a fresh game
observation, info = env.reset()

print("=== Initial Board ===")
print(observation)
print(f"\nInfo: {info}")
# Out:
# === Initial Board ===
# [[0 0 2 1 2 3 3 5 4 5 4 1 3 5]
#  [2 2 3 3 1 5 1 3 4 3 2 3 5 4]
#  [0 5 0 1 1 2 3 4 5 5 2 3 5 3]
#  [3 1 1 3 3 4 1 4 1 2 1 1 3 3]
#  [4 3 2 3 2 1 3 1 3 0 3 2 0 1]
#  [2 4 4 4 0 3 5 1 2 5 0 1 3 4]
#  [1 0 2 5 4 1 3 5 3 1 4 1 4 0]
#  [4 5 3 1 2 1 2 4 4 1 1 5 5 0]
#  [5 5 3 3 3 0 1 4 4 3 4 5 4 3]
#  [1 3 3 3 5 1 0 1 3 2 1 3 4 1]
#  [1 1 1 5 3 4 1 3 1 2 4 4 2 1]
#  [0 4 2 3 1 4 1 3 2 3 3 3 0 4]
#  [0 2 0 0 2 1 5 2 2 2 2 2 5 3]
#  [4 5 0 5 4 4 3 1 4 5 1 0 4 0]]
#
# Info: {'moves': 0, 'moves_left': 25, 'solved': False}

# %%
# Get current board state
board = env.board
print("Current board:")
print(board)

print(f"\nMoves used: {env.moves_used}")
print(f"Solved: {env.solved}")
# Out:
# Current board:
# [[0, 0, 2, 1, 2, 3, 3, 5, 4, 5, 4, 1, 3, 5], [2, 2, 3, 3, 1, 5, 1, 3, 4, 3, 2, 3, 5, 4], [0, 5, 0, 1, 1, 2, 3, 4, 5, 5, 2, 3, 5, 3], [3, 1, 1, 3, 3, 4, 1, 4, 1, 2, 1, 1, 3, 3], [4, 3, 2, 3, 2, 1, 3, 1, 3, 0, 3, 2, 0, 1], [2, 4, 4, 4, 0, 3, 5, 1, 2, 5, 0, 1, 3, 4], [1, 0, 2, 5, 4, 1, 3, 5, 3, 1, 4, 1, 4, 0], [4, 5, 3, 1, 2, 1, 2, 4, 4, 1, 1, 5, 5, 0], [5, 5, 3, 3, 3, 0, 1, 4, 4, 3, 4, 5, 4, 3], [1, 3, 3, 3, 5, 1, 0, 1, 3, 2, 1, 3, 4, 1], [1, 1, 1, 5, 3, 4, 1, 3, 1, 2, 4, 4, 2, 1], [0, 4, 2, 3, 1, 4, 1, 3, 2, 3, 3, 3, 0, 4], [0, 2, 0, 0, 2, 1, 5, 2, 2, 2, 2, 2, 5, 3], [4, 5, 0, 5, 4, 4, 3, 1, 4, 5, 1, 0, 4, 0]]
#
# Moves used: 0
# Solved: False

# %%
# Take a step - flood with a color (0-5)
# Replace 3 below with your chosen color to play
action = 3  # <-- choose a color from 0-5 here

observation, reward, terminated, truncated, info = env.step(action)

print("=== Board After Step ===")
print(observation)
print(f"\nReward: {reward:.2f}")
print(f"Info: moves={info['moves']}, moves_left={info['moves_left']}, solved={info['solved']}")
# Out:
# === Board After Step ===
# [[3 3 2 1 2 3 3 5 4 5 4 1 3 5]
#  [2 2 3 3 1 5 1 3 4 3 2 3 5 4]
#  [0 5 0 1 1 2 3 4 5 5 2 3 5 3]
#  [3 1 1 3 3 4 1 4 1 2 1 1 3 3]
#  [4 3 2 3 2 1 3 1 3 0 3 2 0 1]
#  [2 4 4 4 0 3 5 1 2 5 0 1 3 4]
#  [1 0 2 5 4 1 3 5 3 1 4 1 4 0]
#  [4 5 3 1 2 1 2 4 4 1 1 5 5 0]
#  [5 5 3 3 3 0 1 4 4 3 4 5 4 3]
#  [1 3 3 3 5 1 0 1 3 2 1 3 4 1]
#  [1 1 1 5 3 4 1 3 1 2 4 4 2 1]
#  [0 4 2 3 1 4 1 3 2 3 3 3 0 4]
#  [0 2 0 0 2 1 5 2 2 2 2 2 5 3]
#  [4 5 0 5 4 4 3 1 4 5 1 0 4 0]]
#
# Reward: -1.00
# Info: moves=1, moves_left=24, solved=False

# %%
# Take another step
action = 1  # <-- choose a color from 0-5 here

observation, reward, terminated, truncated, info = env.step(action)

print("=== Board After Step ===")
print(observation)
print(f"\nReward: {reward:.2f}")
print(f"Info: moves={info['moves']}, moves_left={info['moves_left']}, solved={info['solved']}")
# Out:
# === Board After Step ===
# [[1 1 2 1 2 3 3 5 4 5 4 1 3 5]
#  [2 2 3 3 1 5 1 3 4 3 2 3 5 4]
#  [0 5 0 1 1 2 3 4 5 5 2 3 5 3]
#  [3 1 1 3 3 4 1 4 1 2 1 1 3 3]
#  [4 3 2 3 2 1 3 1 3 0 3 2 0 1]
#  [2 4 4 4 0 3 5 1 2 5 0 1 3 4]
#  [1 0 2 5 4 1 3 5 3 1 4 1 4 0]
#  [4 5 3 1 2 1 2 4 4 1 1 5 5 0]
#  [5 5 3 3 3 0 1 4 4 3 4 5 4 3]
#  [1 3 3 3 5 1 0 1 3 2 1 3 4 1]
#  [1 1 1 5 3 4 1 3 1 2 4 4 2 1]
#  [0 4 2 3 1 4 1 3 2 3 3 3 0 4]
#  [0 2 0 0 2 1 5 2 2 2 2 2 5 3]
#  [4 5 0 5 4 4 3 1 4 5 1 0 4 0]]
#
# Reward: -1.00
# Info: moves=2, moves_left=23, solved=False

# %%
# Close environment when done
env.close()
